# %% [markdown]
# ## 01 — Course ground truth (read only)
#
# Use the CSV from the ZoomCamp repo. **Do not generate or save a local copy.**
#
# Next: `02-search-eval.ipynb`

# %%
import pandas as pd
from evaluation_paths import GROUND_TRUTH_CSV

df_ground_truth = pd.read_csv(GROUND_TRUTH_CSV)
ground_truth = df_ground_truth.to_dict(orient="records")

print("file:", GROUND_TRUTH_CSV.resolve())
print("rows:", len(df_ground_truth))
df_ground_truth.head()
# Out:
# file: E:\IT_SPACES\AI\ZoomCamp\LLM\04\2026\Evaluation\data\ground_truth-new.csv
# rows: 395
#                                             question    document
# 0  Is it okay to join the course late if I just f...  74eb249bbf
# 1  Can I still take this course even if I missed ...  74eb249bbf
# 2  If I join after the course has already started...  74eb249bbf
# 3  Do I need to submit my project before submissi...  74eb249bbf
# 4  I’m a bit late to the course—what do I need to...  74eb249bbf

# %%
ground_truth[10]
